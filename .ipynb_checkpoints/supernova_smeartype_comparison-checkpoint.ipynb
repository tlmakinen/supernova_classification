# %% [markdown]
# # Comparing Type Ia SN selection function by simulated spectral "smear type"
#
# A phenomenon called "smearing" often distorts supernova (SN) spectral observation. We're interested in comparing how two different simulated smear types "smear C11" and "smear G10" affect spectroscopic **selection bias** in a population of supernovae.
#
# For background on the general "selected" versus "missed" classification problem, see "selection_function.ipynb"

# %%
# modules we need for the analysis
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf
import pandas as pd
import matplotlib.pyplot as plt

# %%
import clean_fitres

# %%
    
 # first we're going to make the text file readable by pandas using a helper function I wrote
import cleanup

fname = '/mnt/c/Users/lucas/Datasets/bahamas/selection_fitting/{}/FITOPT001.FITRES'.format('Lucas_TEST_smearG10')
cleanup.fitresCleanup(fname)
fname = '/mnt/c/Users/lucas/Datasets/bahamas/selection_fitting/{}/SIMGEN.DAT'.format('Lucas_TEST_smearG10')
cleanup.simgenFileCleanup(fname)

# %%
# first we're going to make the text file readable by pandas using a helper function I wrote
import cleanup

fname = '/mnt/c/Users/lucas/Datasets/bahamas/selection_fitting/Lucas_TEST_smearC11/FITOPT001.FITRES'
cleanup.fitresCleanup(fname)
fname = '/mnt/c/Users/lucas/Datasets/bahamas/selection_fitting/Lucas_TEST_smearC11/SIMGEN.DAT'
cleanup.simgenFileCleanup(fname)

# %%
data_sel = pd.read_csv('/mnt/c/Users/lucas/Datasets/bahamas/selection_fitting/Lucas_TEST_smearG10/FITOPT001_selected.FITRES', sep='\s+')  # selected SNe

# %%
labels = ['Lucas_TEST_smearC11' , 'Lucas_TEST_smearG10']
C11_bulk,C11_sel = clean_fitres.makeMLDataframes(labels[0])

G10_bulk,G10_sel = clean_fitres.makeMLDataframes(labels[1])

smearlist = [[C11_bulk, C11_sel], [G10_bulk, G10_sel]]
# Out:
# /mnt/c/Users/lucas/repositories/supernova_classification/clean_fitres.py:13: RuntimeWarning: invalid value encountered in log10
#   S2mB = [(-2.5 * np.log10(x0) + 10.6) for x0 in data_all['S2x0']]

# %%
from helper_functions import make_latent_plots
# use our helper function to make plots in a couple of lines of code
# inputs: smear label, bulk_data, sel_data

for i in range(len(labels)):    
    make_latent_plots.makeLatentHistograms(labels[i], data_all=smearlist[i][0], data_sel=smearlist[i][1])

# %%
from helper_functions import logreg
for i in range(len(labels)):    
    figpath = '/mnt/c/Users/lucas/repositories/supernova_classification/plots/{}_selectionfunction.png'.format(labels[i][5:])
    logreg.plotSelectionFunction(labels[i], data_all=smearlist[i][0], data_sel=smearlist[i][1], figpath=figpath)

# %%
# take a look at coefficients:

for i in range(len(labels)):    
    phi_test,Z_test,coeff_table = logreg.generateCoeffs(data_all=smearlist[i][0], data_sel=smearlist[i][1])
    
    print(labels[i], "\n", coeff_table)
# Out:
# Lucas_TEST_smearC11
#             0                       1
# 0  Intercept    [26.734531858954558]
# 1       S2mB   [-1.1687590345095855]
# 2        S2c  [-0.13003702403517609]
# 3       S2x1  [0.031751881393517145]
# Lucas_TEST_smearG10
#             0                       1
# 0  Intercept    [26.323747712809624]
# 1       S2mB   [-1.1512190491130083]
# 2        S2c  [-0.08925577803203912]
# 3       S2x1   [0.04615387954353878]
